# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

data = pd.read_csv('/content/archive (2) (2).zip', encoding='latin-1')
data.head()
data.isna().sum()
print(data.columns)
print("Number of columns:", len(data.columns))
data.columns = ['category', 'message', 'extra_column1', 'extra_column2', 'extra_column3']  # Adjust names if necessary
data.head(10)
data.info()
data['category'].value_counts()
data['category'].value_counts().plot(kind='bar')
data['spam']=data['category'].apply(lambda x:1 if x=='spam' else 0)
data.columns
data.head(10)
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')
# Number of columns: 5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       5572 non-null   object
#  1   message        5572 non-null   object
#  2   extra_column1  50 non-null     object
#  3   extra_column2  12 non-null     object
#  4   extra_column3  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB
#   category                                            message extra_column1  \
# 0      ham  Go until jurong point, crazy.. Available only ...           NaN
# 1      ham                      Ok lar... Joking wif u oni...           NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...           NaN
# 3      ham  U dun say so early hor... U c already then say...           NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...           NaN
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...           NaN
# 6      ham  Even my brother is not like to speak with me. ...           NaN
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...           NaN
# 8     spam  WINNER!! As a valued network customer you have...           NaN
# 9     spam  Had your mobile 11 months or more? U R entitle...           NaN
#
#   extra_column2 extra_column3  spam
# 0           NaN           NaN     0
# 1           NaN           NaN     0
# 2           NaN           NaN     1
# 3           NaN           NaN     0
# 4           NaN           NaN     0
# 5           NaN           NaN     1
# 6           NaN           NaN     0
# 7           NaN           NaN     0
# 8           NaN           NaN     1
# 9           NaN           NaN     1
